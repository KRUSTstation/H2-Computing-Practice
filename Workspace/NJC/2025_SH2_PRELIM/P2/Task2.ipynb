# %%
#Task 2.1
import csv

def read_file(filename):
    with open(filename) as f:
        data = [tuple(i) for i in csv.reader(f)]
    
    return data

# %%
#Task 2.2

def get_roles(candidates):
    roles = {}

    for info in candidates:
        if info[1] in roles.keys():
            roles[info[1]].append(info)
        else:
            roles[info[1]] = [info]

    return roles

# %%
#Task 2.3

roles = get_roles(read_file('./Resources/candidates.txt'))

print(f"{'Roles':<15}{'Count':<8}{'Low Score':<8}{'High Score':<8}")
for role, info in roles.items():
    print(f"{role:<15}{len(info):<8}{min(info, key=lambda x: int(x[2]))[2]:<8}{max(info, key=lambda x: int(x[2]))[2]:<8}")
# Out:
# Roles          Count   Low ScoreHigh Score
# Sniper         8       61      95
# Commander      8       48      95
# Medic          7       52      84
# Breacher       7       48      94
# Navigator      7       52      84
# Communication  7       48      83
# 2IC            7       58      92

# %%
#Task 2.4
from random import randint

def form_squads(roles):
    squads = []
    teamN = -1
    print(roles)
    while all([len(i)>0 for _,i in roles.items()]):
        squads.append([])
        teamN+=1
        for role, info in roles.items():
            i = randint(0, len(info)-1)
            squads[teamN].append(info[i])

            info.pop(i)

    return squads
# Out:
# {'Sniper': [('Rufus Schuck', 'Sniper', '79'), ('Paris Curington', 'Sniper', '84'), ('Luanne Lett', 'Sniper', '61'), ('Jalisa Stoudemire', 'Sniper', '76'), ('Chadwick Griffin', 'Sniper', '95'), ('Joella Wessner', 'Sniper', '93'), ('Darlena Crimi', 'Sniper', '80'), ('Carola Tegeler', 'Sniper', '92')], 'Commander': [('Ione Wolfe', 'Commander', '90'), ('Ashely Faye', 'Commander', '87'), ('Ola Markell', 'Commander', '90'), ('Johnna Lecuyer', 'Commander', '48'), ('Jaye Galle', 'Commander', '75'), ('Bill Gates', 'Commander', '55'), ('Fredricka Gormley', 'Commander', '92'), ('Marcella Daigneault', 'Commander', '95')], 'Medic': [('Hillary Curl', 'Medic', '76'), ('Elvia Dubrey', 'Medic', '61'), ('Claudette Bode', 'Medic', '68'), ('Grazyna Kitzman', 'Medic', '57'), ('Virgilio Britt', 'Medic', '52'), ('Marg Thorington', 'Medic', '84'), ('Dannette Raasch', 'Medic', '57')], 'Breacher': [('Juli Barnhill', 'Breacher', '48'), ('Terrence Shannon', 'Breacher', '94'), ('Lashawna Meals', 'Breacher', '68'), ('Phyliss Rolen', 'Breacher', '72'), ('Lanita Sciortino', 'Breacher', '86'), ('Odis Levalley', 'Breacher', '72'), ('Farah Quon', 'Breacher', '80')], 'Navigator': [('Tashia Bowen', 'Navigator', '52'), ('Carolann Kintner', 'Navigator', '73'), ('Angle Linck', 'Navigator', '76'), ('Shaunda Sieg', 'Navigator', '84'), ('See Borne', 'Navigator', '67'), ('Teodoro Negrin', 'Navigator', '84'), ('Apryl Soileau', 'Navigator', '82')], 'Communication': [('Marguerita Mciver', 'Communication', '48'), ('So Atkins', 'Communication', '75'), ('Toney Mcnab', 'Communication', '68'), ('Abdul Boland', 'Communication', '67'), ('Laverna Halpern', 'Communication', '68'), ('Tobias Kimmer', 'Communication', '55'), ('Reiko Stack', 'Communication', '83')], '2IC': [('Sharie Schall', '2IC', '58'), ('Kathlene Collar', '2IC', '73'), ('Hertha Dossantos', '2IC', '64'), ('Lai Lazard', '2IC', '77'), ('Russell Gillison', '2IC', '91'), ('Maryam Brosius', '2IC', '92'), ('Terrance Lauterbach', '2IC', '82')]}
# [[('Carola Tegeler', 'Sniper', '92'),
#   ('Bill Gates', 'Commander', '55'),
#   ('Elvia Dubrey', 'Medic', '61'),
#   ('Phyliss Rolen', 'Breacher', '72'),
#   ('Carolann Kintner', 'Navigator', '73'),
#   ('So Atkins', 'Communication', '75'),
#   ('Lai Lazard', '2IC', '77')],
#  [('Rufus Schuck', 'Sniper', '79'),
#   ('Marcella Daigneault', 'Commander', '95'),
#   ('Hillary Curl', 'Medic', '76'),
#   ('Farah Quon', 'Breacher', '80'),
#   ('Apryl Soileau', 'Navigator', '82'),
#   ('Abdul Boland', 'Communication', '67'),
#   ('Russell Gillison', '2IC', '91')],
#  [('Joella Wessner', 'Sniper', '93'),
#   ('Ola Markell', 'Commander', '90'),
#   ('Grazyna Kitzman', 'Medic', '57'),
#   ('Lashawna Meals', 'Breacher', '68'),
#   ('Shaunda Sieg', 'Navigator', '84'),
#   ('Toney Mcnab', 'Communication', '68'),
#   ('Maryam Brosius', '2IC', '92')],
#  [('Chadwick Griffin', 'Sniper', '95'),
#   ('Johnna Lecuyer', 'Commander', '48'),
#   ('Dannette Raasch', 'Medic', '57'),
#   ('Terrence Shannon', 'Breacher', '94'),
#   ('Angle Linck', 'Navigator', '76'),
#   ('Tobias Kimmer', 'Communication', '55'),
#   ('Hertha Dossantos', '2IC', '64')],
#  [('Darlena Crimi', 'Sniper', '80'),
#   ('Ashely Faye', 'Commander', '87'),
#   ('Claudette Bode', 'Medic', '68'),
#   ('Odis Levalley', 'Breacher', '72'),
#   ('Tashia Bowen', 'Navigator', '52'),
#   ('Marguerita Mciver', 'Communication', '48'),
#   ('Sharie Schall', '2IC', '58')],
#  [('Jalisa Stoudemire', 'Sniper', '76'),
#   ('Fredricka Gormley', 'Commander', '92'),
#   ('Virgilio Britt', 'Medic', '52'),
#   ('Lanita Sciortino', 'Breacher', '86'),
#   ('See Borne', 'Navigator', '67'),
#   ('Laverna Halpern', 'Communication', '68'),
#   ('Kathlene Collar', '2IC', '73')],
#  [('Paris Curington', 'Sniper', '84'),
#   ('Ione Wolfe', 'Commander', '90'),
#   ('Marg Thorington', 'Medic', '84'),
#   ('Juli Barnhill', 'Breacher', '48'),
#   ('Teodoro Negrin', 'Navigator', '84'),
#   ('Reiko Stack', 'Communication', '83'),
#   ('Terrance Lauterbach', '2IC', '82')]]
