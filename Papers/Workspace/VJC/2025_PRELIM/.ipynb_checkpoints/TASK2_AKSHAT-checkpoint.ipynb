# %%
# Task 2.1
class Node:
    def __init__(self):
        self.student_id = -1
        self.student_name = ''
        self.next_pointer = None

    def get_id(self):
        return self.student_id
    def set_id(self, data):
        self.student_id = data

    def get_name(self):
        return self.student_name
    def set_name(self, data):
        self.student_name = data

# %%
# Task 2.2
class LinkedList:
    def __init__(self):
        self.nodes_array = [Node() for _ in range(10)]
        self.start_pointer = -1
        self.next_free_pointer = 0

# %%
# Task 2.3
class LinkedList:
    def __init__(self):
        self.nodes_array = [Node() for _ in range(10)]
        self.start_pointer = -1
        self.next_free_pointer = 0

    def display_records(self):
        if self.start_poitner == -1:
            print('Empty')
            return
        
        current = self.nodes_array[self.start_pointer]
        while current.next_pointer and current.next_pointer != -1:            
            print(f'Student ID: {current.get_id()}, Name: {current.get_name()}', end=' -> ')
            current = self.nodes_array[current.next_pointer]

        print(f'Student ID: {current.get_id()}, Name: {current.get_name()}')

# %%
# Task 2.4
class LinkedList:
    def __init__(self):
        self.nodes_array = [Node() for _ in range(10)]
        self.start_pointer = -1
        self.next_free_pointer = 0

        for i in range(9):
            self.nodes_array[i].next_pointer = i+1

        self.nodes_array[9].next_pointer = -1

    def display_records(self):
        if self.start_poitner == -1:
            print('Empty')
            return
        
        current = self.nodes_array[self.start_pointer]
        while current.next_pointer and current.next_pointer != -1:
            print(f'Student ID: {current.get_id()}, Name: {current.get_name()}', end=' -> ')
            current = self.nodes_array[current.next_pointer]

        print(f'Student ID: {current.get_id()}, Name: {current.get_name()}')

    def insert_record(student_id, student_name):
        if self.next_free_pointer == -1:
            print('No space!')
            return

        node = self.nodes_array[self.next_free_pointer]
        node.set_id(student_id)
        node.set_name(student_name)

        prev = self.nodes_array[self.start_pointer]
        curr_ptr = prev.next_pointer
        current = self.nodes_array[curr_ptr]

        if next_free_pointer != 0:
            while True:
                if node.get_id() < current.get_id():
                    prev.n
                    break
