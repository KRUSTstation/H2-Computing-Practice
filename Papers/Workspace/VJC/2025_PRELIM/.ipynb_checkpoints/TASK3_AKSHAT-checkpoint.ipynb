# %%
# Task 3.1
class Node:
    def __init__(self, team):
        self.team = team
        self.left_ptr = None
        self.right_ptr = None

# %%
# Task 3.2 onwards
import math

class TournamentTree:
    def __init__(self):
        self.root = None

    def create_tree(self, num_of_teams):
        n = int(math.log(num_of_teams, 2))

        self.root = Node()

    def level_order(self):
        '''
        print tree from root
        print out all the nodes of the same level in a row 
        '''
        self._level_order(self.root)
    
    def _level_order(self, node_list):
        '''
        Helper function for internal use
        print tree from node list
        '''
        # convert node_list to a list if it is not
        if not isinstance(node_list, list):
            node_list = [node_list]
        # Stop recursion if the list is empty
        if not node_list:
            return
        # define a list to collect node in next layer
        next_layer = []
        while node_list:
            node = node_list.pop(0) # Remove the first item
            print(node, end = ' ')
            if node.left_ptr:
                next_layer.append(node.left_ptr)
            if node.right_ptr:
                next_layer.append(node.right_ptr)
        print() # print new line after processing a layer
        self._level_order(next_layer)

bst = TournamentTree()
bst.create_tree(8)
bst.level_order()
# Out:
# 3
# None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 45
#      43 bst = TournamentTree()
#      44 bst.create_tree(8)
# ---> 45 bst.level_order()
#
# Cell In[4], line 18, in TournamentTree.level_order(self)
#      13 def level_order(self):
#      14     '''
#      15     print tree from root
#      16     print out all the nodes of the same level in a row
#      17     '''
# ---> 18     self._level_order(self.root)
#
# Cell In[4], line 36, in TournamentTree._level_order(self, node_list)
#      34 node = node_list.pop(0) # Remove the first item
#      35 print(node, end = ' ')
# ---> 36 if node.left_ptr:
#      37     next_layer.append(node.left_ptr)
#      38 if node.right_ptr:
#
# AttributeError: 'NoneType' object has no attribute 'left_ptr'
